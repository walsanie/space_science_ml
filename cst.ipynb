# %% [markdown]
# # Descriptive Analysison Space Mission Data
# ### Waleed Alsanie
# walsanie AT kacst DOT gov DOT sa

# %% [markdown]
# We need first to install the packages we need. We will install **pandas**

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\mohammed\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mohammed\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mohammed\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mohammed\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\mohammed\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\mohammed\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# Before using any package, you need to import it.

# %%
import pandas as pd

# %% [markdown]
# Load the data from the file to a pandas **Dataframe**.

# %%
df = pd.read_csv('Space_Corrected.csv')

# %% [markdown]
# The variable df holds the data now. To view the data, type the variable.

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0 Company Name  \
# 0                0           0       SpaceX
# 1                1           1         CASC
# 2                2           2       SpaceX
# 3                3           3    Roscosmos
# 4                4           4          ULA
# ...            ...         ...          ...
# 4319          4319        4319      US Navy
# 4320          4320        4320         AMBA
# 4321          4321        4321      US Navy
# 4322          4322        4322    RVSN USSR
# 4323          4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# 4319           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.00
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive   29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.00
# 4                       Atlas V 541 | Perseverance   StatusActive  145.00
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4320                           Juno I | Explorer 1  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 9 columns]

# %% [markdown]
# The table has 4324 and 9 columns.
# The columns are:
# 0- Sequence number
# 1- another sequence number
# 2- Company name
# 3- Location of the station.
# 4- Date of the mission.
# 5- More details on the mission.
# 6- Status of the rocket.
# 7- Cost of the mission in million dollars.
# 8- Status of the mission.

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Company Name', 'Location', 'Datum',
#        'Detail', 'Status Rocket', 'Rocket', 'Status Mission'],
#       dtype='object')

# %% [markdown]
# The above statement returns the columns names which can be used to access specific data.
# Now we would like to have some statistics on the data. Let's see some statistics on the costs of the rockets.

# %%
df['Rocket'].describe()
# Out:
# count     964.000000
# mean      153.792199
# std       288.450732
# min         5.300000
# 25%        40.000000
# 50%        62.000000
# 75%       164.000000
# max      5000.000000
# Name: Rocket, dtype: float64

# %% [markdown]
# How many lanuches per company.

# %%
df['Company Name'].value_counts()
# Out:
# Company Name
# RVSN USSR           1777
# Arianespace          279
# CASC                 251
# General Dynamics     251
# NASA                 203
# VKS RF               201
# US Air Force         161
# ULA                  140
# Boeing               136
# Martin Marietta      114
# SpaceX               100
# MHI                   84
# Northrop              83
# Lockheed              79
# ISRO                  76
# Roscosmos             55
# ILS                   46
# Sea Launch            36
# ISAS                  30
# Kosmotras             22
# US Navy               17
# ISA                   13
# Rocket Lab            13
# Eurockot              13
# ESA                   13
# Blue Origin           12
# IAI                   11
# ExPace                10
# ASI                    9
# CNES                   8
# AMBA                   8
# MITT                   7
# JAXA                   7
# Land Launch            7
# UT                     5
# KCST                   5
# CASIC                  5
# Exos                   4
# CECLES                 4
# Arm??e de l'Air        4
# KARI                   3
# SRC                    3
# AEB                    3
# RAE                    2
# OKB-586                2
# Yuzhmash               2
# Landspace              1
# Douglas                1
# EER                    1
# Starsem                1
# Virgin Orbit           1
# IRGC                   1
# i-Space                1
# OneSpace               1
# Sandia                 1
# Khrunichev             1
# Name: count, dtype: int64

# %% [markdown]
# Take only the company with the highest 10 luanches.

# %%
highest_ten = df['Company Name'].value_counts().iloc[0:11]
highest_ten
# Out:
# Company Name
# RVSN USSR           1777
# Arianespace          279
# CASC                 251
# General Dynamics     251
# NASA                 203
# VKS RF               201
# US Air Force         161
# ULA                  140
# Boeing               136
# Martin Marietta      114
# SpaceX               100
# Name: count, dtype: int64

# %% [markdown]
# We want to plot it in a bar char. We need first to install matplotlib.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\mohammed\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mohammed\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\mohammed\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mohammed\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mohammed\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\mohammed\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\mohammed\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mohammed\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\mohammed\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mohammed\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\mohammed\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt

# %%
highest_ten.plot(kind='bar')
plt.ylabel('No. of Missions')
plt.show()

# %% [markdown]
# Number of launches in 2020 per company.

# %%
df[df['Datum'].str.contains('2020')]['Company Name'].value_counts()
# Out:
# Company Name
# CASC            19
# SpaceX          14
# Roscosmos        4
# ULA              4
# Arianespace      4
# ExPace           3
# Rocket Lab       3
# VKS RF           3
# Northrop         2
# MHI              2
# JAXA             1
# IAI              1
# Virgin Orbit     1
# IRGC             1
# ISA              1
# Name: count, dtype: int64

# %%
hbar = df[df['Datum'].str.contains('2020')]['Company Name'].value_counts()
hbar.plot(kind='barh')
plt.xlabel('No. Missions in 2020')
plt.xticks(range(1,21))
plt.show()

# %% [markdown]
# Percentage of successful and failed missions.

# %%
df['Status Mission'].value_counts()
# Out:
# Status Mission
# Success              3879
# Failure               339
# Partial Failure       102
# Prelaunch Failure       4
# Name: count, dtype: int64

# %%
per = df['Status Mission'].value_counts()
per.plot(kind='pie', autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Percentages of Active and Retired rockets.

# %%
act_ret = df[df['Company Name'].str.contains('SpaceX')]['Status Rocket'].value_counts()
act_ret.plot(kind='pie', autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Plotting the number of missions over the years.
# <br>
# Extract the year from the Datum column and count the rows per year.

# %%
years = df['Datum'].str.replace(r'.*,\s+([0-9][0-9][0-9][0-9]).*', r'\1', regex=True).value_counts().sort_index().rename(index=int)
years
# Out:
# Datum
# 1957      3
# 1958     28
# 1959     20
# 1960     39
# 1961     52
#        ...
# 2016     90
# 2017     92
# 2018    117
# 2019    109
# 2020     63
# Name: count, Length: 64, dtype: int64

# %%
print(years.index.dtype)
years.plot()
plt.xlabel('Year')
plt.ylabel('Number of Missions')
plt.xticks(range(1957, 2021, 10))
plt.xticks(rotation=90)
plt.show()
# Out:
# int64
